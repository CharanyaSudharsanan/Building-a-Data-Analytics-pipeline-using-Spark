23aly-inyt-blogSmallThumb.jpg', u'crop_name': u'blogSmallThumb', u'rank': 0, u'height': 50, u'subtype': u'blogSmallThumb', u'legacy': {}, u'subType': u'blogSmallThumb', u'caption': None, u'type': u'image', u'width': 50}, {u'credit': None, u'url': u'images/2018/03/23/opinion/23aly-inyt/23aly-inyt-facebookJumbo.jpg', u'crop_name': u'facebookJumbo', u'rank': 0, u'height': 549, u'subtype': u'facebookJumbo', u'legacy': {}, u'subType': u'facebookJumbo', u'caption': None, u'type': u'image', u'width': 1050}, {u'credit': None, u'url': u'images/2018/03/23/opinion/23aly-inyt/23aly-inyt-filmstrip.jpg', u'crop_name': u'filmstrip', u'rank': 0, u'height': 190, u'subtype': u'filmstrip', u'legacy': {}, u'subType': u'filmstrip', u'caption': None, u'type': u'image', ...

# %%
import math
hits = articles['response']['meta']['hits']
print("hits :" + str(hits))
ls = []
pages = int(math.ceil(hits/10))
for i in range(pages):
    print("collecting page " + str(i))
    articles['page'] = i
    for article in articles['response']['docs']:
        ar = article['web_url'].encode('utf-8')
        if not ar.__contains__("video"):
            ls.append(article['web_url'].encode('utf-8'))
        else:
            continue
print(ls)
# Out:
# hits :355
# collecting page 0
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4
# collecting page 5
# collecting page 6
# collecting page 7
# collecting page 8
# collecting page 9
# collecting page 10
# collecting page 11
# collecting page 12
# collecting page 13
# collecting page 14
# collecting page 15
# collecting page 16
# collecting page 17
# collecting page 18
# collecting page 19
# collecting page 20
# collecting page 21
# collecting page 22
# collecting page 23
# collecting page 24
# collecting page 25
# collecting page 26
# collecting page 27
# collecting page 28
# collecting page 29
# collecting page 30
# collecting page 31
# collecting page 32
# collecting page 33
# collecting page 34
# ['https://www.nytimes.com/2018/03/21/opinion/australia-office-sex-barnaby.html', 'https://www.nytimes.com/2018/03/21/arts/design/italian-art-fondazione-prada-palazzo-strozzi.html', 'https://www.nytimes.com/2018/03/20/nyregion/cynthia-nixon-andrew-cuomo-governor-race-real-progressive.html', 'https://www.nytimes.com/2018/03/15/opinion/trump-republicans-authoritarianism.html', 'https://www.nytimes.com/2018/03/23/us/politics/trump-budget-trade-mcdougal.html', 'https://www.nytimes.com/2018/03/19/us/politics/representative-louise-slaughter-house.html', 'https://www.nytimes.com/2018/03/19/us/politics/supreme-court-pennsylvania-voting-maps.html', 'https://www.nytimes.com/2018/03/23/us/politics/bolton-cambridge-analyticas-facebook-data.html', 'https://www.nytimes.com/2018/03/18/us/politics/nancy-pelosi-democrats-candidates.html', 'https://www.nytimes.com/2018/03/22/us/politics/border-patrol-wall-immigration-trump-senate-democrats.html', 'https://www.nytimes.com/2018/03/21/opinion/australia-office-sex-barnaby.html', 'https://www.nytimes.com/2018/03/21/arts/design/italian-art-fondazione-prada-palazzo-strozzi.html', 'https://www.nytimes.com/2018/03/20/nyregion/cynthia-nixon-andrew-cuomo-governor-race-real-progressive.html', 'https://www.nytimes.com/2018/03/15/opinion/trump-republicans-authoritarianism.html', 'https://www.nytimes.com/2018/03/23/us/politics/trump-budget-trade-mcdougal.html', 'https://www.nytimes.com/2018/03/19/us/politics/representative-louise-slaughter-house.html', 'https://www.nytimes.com/2018/03/19/us/politics/supreme-court-pennsylvania-voting-maps.html', 'https://www.nytimes.com/2018/03/23/us/politics/bolton-cambridge-analyticas-facebook-data.html', 'https://www.nytimes.com/2018/03/18/us/politics/nancy-pelosi-democrats-candidates.html', 'https://www.nytimes.com/2018/03/22/us/politics/border-patrol-wall-immigration-trump-senate-democrats.html', 'https://www.nytimes.com/2018/03/21/opinion/australia-office-sex-barnaby.html', 'https://www.nytimes.com/2018/03/21/arts/design/italian-art-fondazione-prada-palazzo-strozzi.html', 'https://www.nytimes.com/2018/03/20/nyregion/cynthia-nixon-andrew-cuomo-governor-race-real-progressive.html', 'https://www.nytimes.com/2018/03/15/opinion/trump-republicans-authoritarianism.html', 'https://www.nytimes.com/2018/03/23/us/politics/trump-budget-trade-mcdougal.html', 'https://www.nytimes.com/2018/03/19/us/politics/representative-louise-slaughter-house.html', 'https://www.nytimes.com/2018/03/19/us/politics/supreme-court-pennsylvania-voting-maps.html', 'https://www.nytimes.com/2018/03/23/us/politics/bolton-cambridge-analyticas-facebook-data.html', 'https://www.nytimes.com/2018/03/18/us/politics/nancy-pelosi-democrats-candidates.html', 'https://www.nytimes.com/2018/03/22/us/politics/border-patrol-wall-immigration-trump-senate-democrats.html', 'https://www.nytimes.com/2018/03/21/opinion/australia-office-sex-barnaby.html', 'https://www.nytimes.com/2018/03/21/arts/design/italian-art-fondazione-prada-palazzo-strozzi.html', 'https://www.nytimes.com/2018/03/20/nyregion/cynthia-nixon-andrew-cuomo-governor-race-real-progressive.html', 'https://www.nytimes.com/2018/03/15/opinion/trump-republicans-authoritarianism.html', 'https://www.nytimes.com/2018/03/23/us/politics/trump-budget-trade-mcdougal.html', 'https://www.nytimes.com/2018/03/19/us/politics/representative-louise-slaughter-house.html', 'https://www.nytimes.com/2018/03/19/us/politics/supreme-court-pennsylvania-voting-maps.html', 'https://www.nytimes.com/2018/03/23/us/politics/bolton-cambridge-analyticas-facebook-data.html', 'https://www.nytimes.com/2018/03/18/us/politics/nancy-pelosi-democrats-candidates.html', 'https://www.nytimes.com/2018/03/22/us/politics/border-patrol-wall-immigration-trump-senate-democrats.html', 'https://www.nytimes.com/2018/03/21/opinion/australia-office-sex-barnaby.html', 'https://www.nytimes.com/2018/03/21/arts/design/italian-art-fondazione-prada-palazzo-strozzi.html', 'https://www.nytimes.com/2018/03/20/nyregion/cynthia-ni ...

# %%
from bs4 import BeautifulSoup
import requests
import unicodedata
import re

i = 0;
for x in ls[:]:
    page = requests.get(x)
    soup = BeautifulSoup(page.content, 'html.parser')
    soup = soup.find('article')
    for script in soup(["script", "style"]):
        script.extract() 
    text = soup.text.strip()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = ' '.join(chunk for chunk in chunks if chunk)
    artc1 = text.encode('utf-8').strip()
    #artc = artc + "charanya" + artc1
    clean_a = re.sub(r"[^a-zA-Z]+", ' ', artc1)
    clean_a = ' '.join([w for w in clean_a.split() if len(w)>1])
    #clean_a = clean_a.lower()
    clean_a = re.sub("New York Times", ' ', clean_a, flags=re.I)
    clean_a = re.sub("story", ' ', clean_a, flags=re.I)
    clean_a = re.sub("reading", ' ', clean_a, flags=re.I)
    clean_a = re.sub("continue", ' ', clean_a, flags=re.I)
    clean_a = re.sub("house", ' ', clean_a, flags=re.I)
    clean_a = re.sub("times", ' ', clean_a, flags=re.I)
    clean_a = re.sub("special", ' ', clean_a, flags=re.I)
    clean_a = re.sub("would", ' ', clean_a, flags=re.I)
    clean_a = re.sub("could", ' ', clean_a, flags=re.I)
    clean_a = re.sub("photo", ' ', clean_a, flags=re.I)
    clean_a = re.sub("today", ' ', clean_a, flags=re.I)
    clean_a = re.sub("appears", ' ', clean_a, flags=re.I)
    fname = "Sports" + str(i);
    i = i + 1;
    with open(fname + ".txt", "w ") as text_file:
        text_file.write("%s" % clean_a)
